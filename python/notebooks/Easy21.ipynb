# %%
import sys
sys.path.append("..")
import easy21.core as easy21
from easy21 import dev
from easy21 import linfa
import numpy as np
import matplotlib.pyplot as pyplot

monte_carlo_V = np.loadtxt('../../clojure/data.csv')

# %%
# %matplotlib notebook
dev.plot_V(dev.train_linfa(1000000, 0.2))
# Out:
# [ 0.20878757  0.04966353 -0.21688792  0.1284576   0.08241639  0.06562186
#  -0.01354245 -0.04964833  0.32087004 -0.14243019]
# <img src="data:image/png;base64,...">

# %%
monte_carlo_V = np.loadtxt('../../clojure/data.csv')
dev.plot_msq_errors(dev.train_linfa, monte_carlo_V, 10000)
# Out:
# [ 0.22532352  0.02470535 -0.21792116 -0.07803928 -0.01432494 -0.0247636
#  -0.07590671  0.04805666  0.07755105 -0.19035608]
# [ 0.13619438  0.00371113 -0.21172782  0.18154028 -0.03768176  0.18293776
#   0.02956807  0.06448567  0.1078627  -0.14450297]
# [ 0.24036903 -0.062996   -0.10282049  0.02004923 -0.08349857  0.02993685
#   0.05388056  0.02409365 -0.01073868 -0.22107478]
# [ 0.19589459  0.06416037 -0.13116141  0.04096596  0.04739805  0.08952704
#   0.04374948  0.05094007  0.0251479  -0.14320052]
# [ 0.15989879  0.14910288 -0.21018716  0.02276222  0.10217803 -0.00124772
#   0.09757634  0.02155867  0.06019203 -0.11654974]
# [ 0.07382683  0.08398298 -0.18228072 -0.0247402   0.08292224 -0.02370833
#  -0.19650245 -0.01314512 -0.00290426 -0.20378889]
# [ 0.17968903  0.02656492 -0.24349642  0.0752252   0.0511561   0.09539562
#  -0.00038416  0.06616638  0.03120122 -0.1730205 ]
# [ 0.10856313  0.09785413 -0.17165868 -0.00902029  0.01944136  0.02127073
# ...

# %%
monte_carlo_V = np.loadtxt('../../clojure/data.csv')
dev.plot_msq_errors(dev.train_linfa, monte_carlo_V, 10000)
# Out:
# [ 0.09380237  0.09978111 -0.35680539  0.14333592  0.04891919  0.1259525
#   0.05272463  0.09327383  0.05239642 -0.20845097]
# [ 0.18604803  0.06377139 -0.19805168 -0.0015164   0.08346349  0.03131789
#  -0.00973162  0.02963916  0.00821822 -0.1846406 ]
# [ 0.16047512  0.06740626 -0.28887794  0.03918631  0.01215581  0.02605342
#  -0.0037933   0.06371     0.03705891 -0.18191524]
# [ 0.12072207  0.03165364 -0.10073297  0.04672703  0.07648189  0.02870303
#   0.03522683  0.06757046  0.05797578 -0.17950155]
# [ 0.20328931  0.0559709  -0.34411363 -0.03666222  0.02171418 -0.0234152
#   0.11610277 -0.00466949 -0.00834271 -0.17874505]
# [ 0.17262613  0.0148713  -0.09295713  0.09842704 -0.02054549 -0.01541922
#   0.0274388   0.07975891  0.02346452 -0.12733404]
# [ 0.12575826  0.00914488 -0.23049698  0.04111682  0.02005736  0.17944815
#   0.04293757  0.06049358  0.0482975  -0.19756208]
# [ 0.34529242 -0.09443929 -0.16407999 -0.06763883  0.04960444 -0.05004798
# ...

# %%
dev.plot_msq_errors(dev.train_linfa, monte_carlo_V, 10000)
# Out:
# [ 0.31222379  0.03057299 -0.38604891  0.02291875 -0.11091439  0.04819888
#   0.01574224  0.03523753  0.02429172 -0.26170639]
# [ 0.13928513 -0.01101592 -0.15250511 -0.02604293  0.24849553  0.01518714
#  -0.10867177  0.02141872  0.06312547 -0.10325353]
# [ 0.20451145  0.12183006 -0.14492079  0.07507456  0.05139502  0.14758391
#   0.01372162 -0.00979523  0.03449113 -0.18812473]
# [ 0.14366395 -0.06647365 -0.1832819   0.07885497 -0.03377631 -0.02570079
#   0.00353125  0.04461121  0.0993016  -0.13760537]
# [ 0.24334966  0.05740255 -0.28404856 -0.08314285  0.0425554   0.0939736
#   0.10992734 -0.01090734 -0.00037534 -0.15617204]
# [ 0.21460112  0.14088946 -0.21011721  0.11211293  0.03153126 -0.02326041
#  -0.08801962 -0.02719984  0.12324168 -0.17416312]
# [ 0.19079268  0.01666096 -0.2147967   0.02555232  0.04836004  0.09927913
#  -0.00933873 -0.03849294  0.02715625 -0.16044875]
# [  2.20014725e-01  -3.75704395e-02  -3.08346118e-01   7.15548050e-02
# ...

# %%
monte_carlo_V = np.loadtxt('../../clojure/data.csv')
dev.plot_msq_errors(dev.train_linfa, monte_carlo_V, 10000)
# Out:
# [ 0.28512601  0.08631206 -0.22083921  0.00724019 -0.14255797  0.08944584
#  -0.02702928 -0.08497771  0.08834975 -0.18219999]
# [ 0.14850915  0.01865784 -0.15787657 -0.11392557 -0.06326854  0.03430003
#  -0.01181641 -0.08894951  0.05237981 -0.22410425]
# [ 0.13055569  0.04824777 -0.20943001 -0.02894078  0.11879897  0.03887776
#  -0.17091638 -0.04003925  0.06902055 -0.1541495 ]
# [ 0.27362939  0.10568435 -0.12030714  0.2026098  -0.02826593  0.14916777
#   0.12295779 -0.05535975  0.07269052 -0.16896806]
# [ 0.13986961 -0.0010554  -0.23598687 -0.03222432  0.03034731 -0.03812505
#  -0.05435454  0.07389686  0.05331691 -0.19108966]
# [ 0.14809939  0.06968957 -0.16146923  0.02217846  0.13900055  0.03714134
#  -0.08067572 -0.03309889  0.07178939 -0.16594281]
# [ 0.1554472  -0.00275337 -0.23678003  0.07962675 -0.01214132 -0.00298442
#  -0.08047572  0.0471917   0.10377097 -0.17451009]
# [ 0.11343637 -0.05811467 -0.22566525  0.13951514 -0.05665303 -0.00832515
# ...

# %%
monte_carlo_V = np.loadtxt('../../clojure/data.csv')
dev.plot_msq_errors(dev.train_linfa, monte_carlo_V, 10000)
# Out:
# <img src="data:image/png;base64,...">

# %%
dev.plot_learning_rate(monte_carlo_V, dev.train_Qs_linfa(10000, 0.5, 0.01))

# %%
feature = linfa.prepare_feature(linfa.ex_feature_slow)
dev.plot_learning_rate(monte_carlo_V, dev.train_Qs_linfa(25000, 0.5, 0.01, feature))

# %% [markdown]
# Whoa, this is pretty awesome. But why, but why, but why.
